# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('titanic1.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df = df.drop(['PassengerId', 'Name', 'Ticket'], axis = 1)

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         0       3    male  22.0      1      0   7.2500   NaN        S
# 1         1       1  female  38.0      1      0  71.2833   C85        C
# 2         1       3  female  26.0      0      0   7.9250   NaN        S
# 3         1       1  female  35.0      1      0  53.1000  C123        S
# 4         0       3    male  35.0      0      0   8.0500   NaN        S

# %%
dummy = pd.get_dummies(df['Sex'])
df = pd.concat([df, dummy], axis = 1)
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked  \
# 0         0       3    male  22.0      1      0   7.2500   NaN        S
# 1         1       1  female  38.0      1      0  71.2833   C85        C
# 2         1       3  female  26.0      0      0   7.9250   NaN        S
# 3         1       1  female  35.0      1      0  53.1000  C123        S
# 4         0       3    male  35.0      0      0   8.0500   NaN        S
#
#    female  male
# 0       0     1
# 1       1     0
# 2       1     0
# 3       1     0
# 4       0     1

# %%
df = df.drop('Sex', axis = 1)
df.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare Cabin Embarked  female  male
# 0         0       3  22.0      1      0   7.2500   NaN        S       0     1
# 1         1       1  38.0      1      0  71.2833   C85        C       1     0
# 2         1       3  26.0      0      0   7.9250   NaN        S       1     0
# 3         1       1  35.0      1      0  53.1000  C123        S       1     0
# 4         0       3  35.0      0      0   8.0500   NaN        S       0     1

# %%
dum = pd.get_dummies(df['Embarked'])
df = pd.concat([df,dum], axis = 1)
df.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare Cabin Embarked  female  male  \
# 0         0       3  22.0      1      0   7.2500   NaN        S       0     1
# 1         1       1  38.0      1      0  71.2833   C85        C       1     0
# 2         1       3  26.0      0      0   7.9250   NaN        S       1     0
# 3         1       1  35.0      1      0  53.1000  C123        S       1     0
# 4         0       3  35.0      0      0   8.0500   NaN        S       0     1
#
#    C  Q  S
# 0  0  0  1
# 1  1  0  0
# 2  0  0  1
# 3  0  0  1
# 4  0  0  1

# %%
from numpy import NaN, nan

# %%
df = df.drop("Embarked", axis = 1)
df.tail()
# Out:
#      Survived  Pclass   Age  SibSp  Parch   Fare Cabin  female  male  C  Q  S
# 886         0       2  27.0      0      0  13.00   NaN       0     1  0  0  1
# 887         1       1  19.0      0      0  30.00   B42       1     0  0  0  1
# 888         0       3   NaN      1      2  23.45   NaN       1     0  0  0  1
# 889         1       1  26.0      0      0  30.00  C148       0     1  1  0  0
# 890         0       3  32.0      0      0   7.75   NaN       0     1  0  1  0

# %%
m = df['Age'].mean()
m
# Out:
# 29.69911764705882

# %%
df = df['Age'].replace(to_replace = [NaN], value = 29.7)
df.tail()
# Out:
# 886    27.0
# 887    19.0
# 888    29.7
# 889    26.0
# 890    32.0
# Name: Age, dtype: float64

# %%
n = df['Cabin'].mode()
n
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-3a0fc08f08c2> in <module>
# ----> 1 n = df['Cabin'].mode()
#       2 n
#
# c:\users\prashant shekhar\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# c:\users\prashant shekhar\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4373         try:
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#    4377             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Cabin'
